# %% [markdown]
# # <div align="center" >Lab 6 | Quadratic equation -Classic -Po Shen Loh</div>#
# ###David Alexander Núñez Quintero

# %%
import cmath  # libreria para números complejos
import math
import matplotlib.pyplot as plt
import numpy as np

# %%
def classical_method(a,b,c): #esta función calculará las raices para polinómios de orden 2 mediante el metodo clásico
  disc=b**2-(4*a*c) #discriminante
  
  if disc>=0: 
    root1=((-b)+math.sqrt(disc))/(2*a)
    root2=((-b)-math.sqrt(disc))/(2*a)
  else:
    root1=(-b+cmath.sqrt(disc))/(2*a)
    root2=(-b-cmath.sqrt(disc))/(2*a)
  print("Método clásico")
  print("raiz 1: {0} , raíz 2: {1}".format(root1,root2))

# %%
def Po_Shen_Loh_method(a,b,c):#función que calcula las raices de un polinomió de orden 2 , mediante el nuevo método Po Shen Loh

  if a!=1: #si a!=1 normalizamos la ecuación para usar el método
    inv=1/a  
    b*=inv
    c*=inv

  sum_flag=-b/2           
  sum_flag_2=(b**2)/4
  u_2=sum_flag_2-c #viene a ser una especie de discriminante para determinar si es una raiz compleja o no

  if u_2<0:
    root1=sum_flag+cmath.sqrt(u_2)
    root2=sum_flag-cmath.sqrt(u_2)
  else:
    root1=sum_flag+math.sqrt(u_2)
    root2=sum_flag-math.sqrt(u_2)
  print("Método Po Shen Loh ")
  print("raiz 1: {0} , raíz 2: {1}".format(root1,root2))
  return root1,root2

# %% [markdown]
# ### 1. Plot the following functions in a x range that include the vertex and the roots (if there are roots)

# %% [markdown]
# *  $x^2$

# %%
def f(elem):
  return elem**2

roots=np.array(0)#raices del polinomio x**2
x = np.linspace(-10.0,10.0,500) #generamos 500 puntos equidistantes entre -10 y 10 para evaluarlos en la función
fig, ax = plt.subplots()
ax.plot(x,f(x),roots,roots*0,"ro") #evaluamos los puntos y generamos el plot
ax.axhline(y=0, color='k')      #linea eje y
ax.axvline(x=0, color='k')      #linea eje x
ax.grid(True, which='both')    #Generamos un grid o cuadrícula
plt.title('f(x)=x**2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# * $(x-1)^2$

# %%
def f(elem):
  return (elem-1)**2
roots=np.array(1) #raices del polinomio
x = np.linspace(-5.0,5.0,500)#generamos 500 puntos equidistantes entre -10 y 10 para evaluarlos en la función
fig, ax = plt.subplots()
ax.plot(x,f(x),roots,roots*0,"ro")#evaluamos los puntos y generamos el plot
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=(x-1)**2')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# * $x^2 - 1$

# %%
def f(elem):
  return elem**2 -1
roots=np.array([1,-1]) #raices del polinomio
x = np.linspace(-5.0,5.0,500)#generamos 500 puntos equidistantes entre -10 y 10 para evaluarlos en la función
fig, ax = plt.subplots()
ax.plot(x,f(x),roots,roots*0,"ro")#evaluamos los puntos y generamos el plot
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x**2-1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# *  $x^2 +1$

# %%
def f(elem):
  return elem**2 +1
#En este caso el polinomio no tiene raices reales
x = np.linspace(-5.0,5.0,500)#generamos 500 puntos equidistantes entre -10 y 10 para evaluarlos en la función
fig, ax = plt.subplots()
ax.plot(x,f(x))#evaluamos los puntos y generamos el plot
ax.axhline(y=0, color='k')
ax.axvline(x=0, color='k')
ax.grid(True, which='both')
plt.title('f(x)=x**2+1')
plt.xlabel('x')
plt.ylabel('f(x)')
# Out:
# Text(0, 0.5, 'f(x)')

# %% [markdown]
# ###2. Apply the Classic and Po Shen Loh ‘s methods for solving the following quadratic equations###

# %% [markdown]
# ---
# * $x^2=0$

# %%
classical_method(1,0,0)
# Out:
# Método clásico
# raiz 1: 0.0 , raíz 2: 0.0

# %%
Po_Shen_Loh_method(1,0,0)
print("")
# Out:
# Método Po Shen Loh
# raiz 1: 0.0 , raíz 2: 0.0

# %% [markdown]
# ---
# * $(x-1)^2=0$

# %%
classical_method(1,-2,1)
# Out:
# Método clásico
# raiz 1: 1.0 , raíz 2: 1.0

# %%
Po_Shen_Loh_method(1,-2,1)
print("")
# Out:
# Método Po Shen Loh
# raiz 1: 1.0 , raíz 2: 1.0

# %% [markdown]
# ---
# * $x^2-1=0$

# %%
classical_method(1,0,-1)
# Out:
# Método clásico
# raiz 1: 1.0 , raíz 2: -1.0

# %%
Po_Shen_Loh_method(1,0,-1)
print("")
# Out:
# Método Po Shen Loh
# raiz 1: 1.0 , raíz 2: -1.0

# %% [markdown]
# ---
#
# * $x^2+1=0$

# %%
classical_method(1,0,1)
# Out:
# Método clásico
# raiz 1: 1j , raíz 2: -1j

# %%
Po_Shen_Loh_method(1,0,1)
print("")
# Out:
# Método Po Shen Loh
# raiz 1: 1j , raíz 2: -1j

# %% [markdown]
# ###3. to plot the newton fractals for the corresponding complex quadratic polynomials

# %%
def newton_set1(f,df,roots,z_c_r=0, z_c_i=0, zh = 5, zw=5, width=500, height=500, zoom=1,  niter=256,m=1):
    """ Fractals using newton-raphson """

    # Pixels array
    pixels = np.arange(width*height*3, dtype=np.uint32).reshape(height, width, 3)

    h = 1e-7 # step size for numerical derivative
    eps = 1e-3 # max error allowed

    # Bounding roots
   

    # Color multiplication factor
    # NOTE: Increasing this darkens the image and lightens it otherwise
    multcol = [[5,0,0],[0,5,0],[0,0,5]]
    r=[255,0,0]
    g=[0,255,0]
    b=[0,0,255]
    for y in range(height):
            zy =   z_c_i+(((y-(height/2))/height)*zh*zoom)

            for x in range(width):
                zx = z_c_r+ (((x-(width/2))/width)*zw*zoom)

                # Mapping real -> complex plane
                z = complex(zx, zy)
                
                count = 0
                
                for i in range(niter):
                    # complex numerical derivative
                    dz = df(z)
                    if dz == 0:
                        
                        break

                    count += 1
                    if count > 255:
                      
                      break
                   
                    znext = z - m*f(z) / dz # Newton iteration   m es la multiplicidad de la raiz, de esta manera converge más rápido

                    if abs(znext - z) < eps: # stop when close enough to any root
    
                        break
                
                    z = znext

                # Pixels colored using the roots
                flag=True
                
                for i,val in enumerate(roots):
                  
                  if abs(z-val)<=eps:
                      # color red
                      
                      pixels[height-y-1,x] = (r[i] - count*multcol[i][0], g[i]- count*multcol[i][1], b[i]- count*multcol[i][2])
                      flag=False
                      break
                  
                  
                if flag:   
                    pixels[height-y-1,x] = (0, 0, 0)
 
    return pixels

def display1(name,f,df,roots,z_c_r=0, z_c_i=0, zh = 1, zw=1, width=500, height=500, zoom=1,  niter=256,m=1):
    """ Display a newton-raphson fractal """
    print("Z region from (",z_c_r+ (((0-(width/2))/width)*zw*zoom),",",z_c_i+(((0-(height/2))/height)*zh*zoom) ,") to (",z_c_r+ (((width-(width/2))/width)*zw*zoom),",",z_c_i+(((height-(height/2))/height)*zh*zoom),")")
    pimg = newton_set1(f,df,roots,z_c_r=z_c_r, z_c_i=z_c_i, zh = zh, zw=zw, width=width, height=width, zoom=zoom,  niter=niter,m=m)
    plt.title('Newton Fractal f(z)='+name)
    plt.xlabel("real"+"("+ str(z_c_r+ (((0-(width/2))/width)*zw*zoom))+","+str(z_c_r+ (((width-(width/2))/width)*zw*zoom))+")")
    plt.ylabel("imaginary"+"("+str(z_c_i+(((0-(height/2))/height)*zh*zoom))+","+str(z_c_i+(((height-(height/2))/height)*zh*zoom)) +")")
    plt.imshow(pimg)
    plt.show()

# %% [markdown]
# - $x^2$

# %%
def eq1(x):
  return x**2

def deq1(x):
  return 2*x

# %%
roots=list(Po_Shen_Loh_method(1,0,0))
print(roots)
display1("x**2",eq1,deq1,roots,zoom=5,m=2) #m es la multiplicidad de las raices
# Out:
# Método Po Shen Loh
# raiz 1: 0.0 , raíz 2: 0.0
# [0.0, 0.0]
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# - $(x-1)^2$

# %%
def eq1(x):
  return (x-1)**2

def deq1(x):
  return 2*(x-1)

# %%
roots=list(Po_Shen_Loh_method(1,-2,1))
print(roots)
display1("(x-1)**2",eq1,deq1,roots,zoom=5,m=2)
# Out:
# Método Po Shen Loh
# raiz 1: 1.0 , raíz 2: 1.0
# [1.0, 1.0]
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# - $x^2-1$

# %%
def eq1(x):
  return x**2-1

def deq1(x):
  return 2*x

# %%
roots=list(Po_Shen_Loh_method(1,0,-1))
display1("x**2-1",eq1,deq1,roots,zoom=5)
# Out:
# Método Po Shen Loh
# raiz 1: 1.0 , raíz 2: -1.0
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# - $x^2+1$

# %%
def eq1(x):
  return x**2+1

def deq1(x):
  return 2*x

# %%
roots=list(Po_Shen_Loh_method(1,0,1))
display1("x**2+1",eq1,deq1,roots,zoom=5)
# Out:
# Método Po Shen Loh
# raiz 1: 1j , raíz 2: -1j
# Z region from ( -2.5 , -2.5 ) to ( 2.5 , 2.5 )

# %% [markdown]
# ### 4. Plot the Newton iterates for points on the positive and negative axes for the complex quadratic polynomials in 3. Give an interpretation of the results.

# %% [markdown]
# - $x^2$

# %%
def eq1(x):
  return x**2

def deq1(x):
  return 2*x

# %%
def plot_iteration(z,eq1,deq1,title):
  r=[]
  i=[]
  for k in range(100):
    dz = deq1(z)
    z = z - eq1(z) / dz # Newton iteration
    r.append(np.real(z))
    i.append(np.imag(z))
    
  plt.title('Newton iterates form '+title)
  plt.plot(r)
  plt.ylabel('Real part')
  plt.show()
  plt.plot(i)
  plt.ylabel('Imagnary part')
  plt.show()

# %%
plot_iteration(-10+0.0j,eq1,deq1,"-10+0.0j")
plot_iteration(10+0.0j,eq1,deq1,"10+0.0j")
plot_iteration(0+10.0j,eq1,deq1,"0+10.0j")
plot_iteration(0-10.0j,eq1,deq1,"0-10.0j")
plot_iteration(1+0j,eq1,deq1,"0+1j")

# %% [markdown]
# ####Análisis
# Cuando nos encontramos en el eje positivo o negativo de la parte real, lo que ocurre es que la parte imaginaria se mantiene en 0, y la parte real inicia a converger hacia su raíz en este caso es cero, aproximadamente converge en 5 pasos. por otro lado cuando nos encontramos en el eje positivo o negativo de la parte imaginaria, lo que ocurre es que la parte real se queda en cero, mientras la parte imaginaria inicia a converger hacia cero, la cual es la raíz. En este caso si tomamos puntos en los ejes la convergencia ocurre relativamente rapido aproximadamente en 5 o 6 pasos
#
# <br>
# <hr>

# %% [markdown]
# - $(x-1)^2$

# %%
def eq2(x):
  return (x-1)**2

def deq2(x):
  return 2*(x-1)

# %%
#plot_iteration(-10+0.0j,eq2,deq2,"-10+0.0j")
#plot_iteration(+10+0.0j,eq2,deq2,"10+0.0j")
plot_iteration(0+10.0j,eq2,deq2,"0+10.0j")
plot_iteration(0-10.0j,eq2,deq2,"0-10.0j")

# %% [markdown]
# ####Análisis
# Cuando nos encontramos en el eje real, la parte real tiende a 1 mientras que la parte imaginaria se mantiene en cero, lo que ocasiona es que surga un error de division por cero, pues al converger la parte real a 1, hará que $dz$ de cero y se estaría dividiendo por cero.Cuando nos encontramos en la parte positiva del eje imaginario, la parte real se va rapidamente para  "1", mientras que en la parte imaginaria se va rapidamente para cero, lo mismo ocurre para la parte negativa del eje imaginario.
# <br>
# <hr>

# %% [markdown]
# - $x^2-1$

# %%
def eq3(x):
  return x**2-1

def deq3(x):
  return 2*x

# %%
plot_iteration(-10+0.0j,eq3,deq3,"-10+0.0j")
plot_iteration(+10+0.0j,eq3,deq3,"10+0.0j")
plot_iteration(0+10.0j,eq3,deq3,"0+10.0j")
plot_iteration(0-10.0j,eq3,deq3,"0-10.0j")

# %% [markdown]
# ####Análisis
# Cuando nos encontramos en el eje negativo de la parte real , la parte imaginaria se mantiene en cero mientras que la parte real converge rapidamente a "-1", lo mismo ocurre en la parte positiva del eje real con la diferencia de que esta converge a "1". por otro lado cuando nos encontramos en la parte negativa del eje imaginario, la parte real se mantiene constante en cero, mientras que en la parte imaginaria se observa divergencia. lo mismo ocurre para la parte positiva del eje imaginario
# <br>
# <hr>

# %% [markdown]
# - $x^2+1$

# %%
def eq4(x):
  return x**2+1

def deq4(x):
  return 2*x

# %%
plot_iteration(-10+0.0j,eq4,deq4,"-10+0.0j")
plot_iteration(+10+0.0j,eq4,deq4,"10+0.0j")
plot_iteration(0+10.0j,eq4,deq4,"0+10.0j")
plot_iteration(0-10.0j,eq4,deq4,"0-10.0j")

# %% [markdown]
# ####Análisis
# Cuando nos encontramos en el eje negativo de la parte real , la parte imaginaria se mantiene en cero mientras que la parte real diverge, lo mismo ocurre en la parte positiva del eje real . por otro lado cuando nos encontramos en la parte negativa del eje imaginario, la parte real se mantiene constante en cero, mientras que en la parte imaginaria converge rapidamente a "-1". lo mismo ocurre para la parte positiva del eje imaginario con la diferencia que converge a "1".
# <br>
# <hr>

# %% [markdown]
# ###5. Plot he Newton iterates for points on the diagonals in the four quadrants and 0.0 + 0.0j for the complex quadratic polynomials in 3.

# %% [markdown]
# - $x^2$

# %%
plot_iteration(-10+10.0j,eq1,deq1,"-10+10.0j")
plot_iteration(10+10.0j,eq1,deq1,"10+10.0j")
plot_iteration(-10-10.0j,eq1,deq1,"-10-10.0j")
plot_iteration(10-10.0j,eq1,deq1,"10-10.0j")

# %% [markdown]
# ####Análisis
# En este caso caundo se parte de puntos de cualquira de las 4 diagonales, sin incluir el punto 0+0j lo que ocurre es que tanto la parte real como imaginaria converge a cero.
# <br>
# <hr>

# %% [markdown]
# - $(x-1)^2$

# %%
plot_iteration(-10+10.0j,eq2,deq2,"-10+10.0j")
plot_iteration(10+10.0j,eq2,deq2,"10+10.0j")
plot_iteration(-10-10.0j,eq2,deq2,"-10-10.0j")
plot_iteration(10-10.0j,eq2,deq2,"10-10.0j")

# %% [markdown]
# ####Análisis
# En este caso cuando se parte de puntos de la diagonal del cuadrante 2, la parte real converge a "1"mientras que la parte imaginaria se va para cero, ocurre lo mismo en la diagonal del cuadrante 1. Cuando se toman puntos de la diagonal del cuadrante 3 y 4, lo que ocurre es que la parte real converge a "1", y la parte imaginaria converge a cero.
# <br>
# <hr>

# %% [markdown]
# - $x^2-1$

# %%
plot_iteration(-10+10.0j,eq3,deq3,"-10+10.0j")
plot_iteration(10+10.0j,eq3,deq3,"10+10.0j")
plot_iteration(-10-10.0j,eq3,deq3,"-10-10.0j")
plot_iteration(10-10.0j,eq3,deq3,"10-10.0j")

# %% [markdown]
# ####Análisis
# En este caso cuando se parte de puntos de las diagonales del cuadrante 2 o 3 lo que ocurre es una convergencia muy rapida en la parte real hacia "-1" y en la parte imaginaria hacia cero. Mientras que si se parte de puntos de la diagonal del cuadrante 1 y 4, lo que ocurre es una convergencia rapida en la parte real hacia "1" y en la parte imaginaria hacia cero.
# <br>
# <hr>

# %% [markdown]
# - $x^2+1$

# %%
plot_iteration(-10+10.0j,eq4,deq4,"-10+10.0j")
plot_iteration(10+10.0j,eq4,deq4,"10+10.0j")
plot_iteration(-10-10.0j,eq4,deq4,"-10-10.0j")
plot_iteration(10-10.0j,eq4,deq4,"10-10.0j")

# %% [markdown]
# ####Análisis
# En este caso cuando se parte de puntos de las diagonales del cuadrante 4 o 3 lo que ocurre es una convergencia muy rapida en la parte imaginaria hacia "-1" y en la parte real hacia cero. Mientras que si se parte de puntos de la diagonal del cuadrante 1 o 2, lo que ocurre es una convergencia rapida en la parte imaginaria hacia "1" y en la parte real hacia cero.
# <br>
# <hr>

# %% [markdown]
# ###Caso cuando se parte de 0+0j:
# Lo que va a ocurrir es un error, pues se va a generar division por cero, esto se debe a la asignacion z=z-eq(z)/dz, en este caso dz siempre es 2*z para 3 de los 4 casos, y como z=0, se va a tener una división por cero. para el otro caso, precisamente el caso $(x-1)^2$ dz en principio no es cero, pero la parte real de $z$ va a ir convergiendo a 1, cuando esta converge $dz=0$ y se va a producir division por cero y produce el error, sin embargo esta si converge o se acerca mucho a su raiz, las anteriores no.

# %%
#plot_iteration(0-0.j,eq1,deq1,"0-0.0j") se genera un error de division by zero, esto acausa de que dz=0 y se tiene que z=z-eq1(z)/dz
